# %%
# from utils import *
from fastai2.vision.widgets import *
# from fastai.vision import *
from fastai2.vision.all import *
import zipfile
from pathlib import Path
from shutil import copyfile

# %%
# Upload a new zipped batch
# Unzip it
# Manually copy over the new files to the training_images folder
with zipfile.ZipFile('batch-2-all-jpegs-no-folders.zip', 'r') as zip_ref:
    zip_ref.extractall('data/uploads/')

# %%
# don't think we need this: rug_types = ['over','angle','corner_light','corner_grey','corner_dark','back','detail','lifestyle']
path = Path('data/training_images')
len(path.ls())
path.ls()
# Out:
# [Path('data/training_images/06869-0007_07-Detail.jpeg'),
#  Path('data/training_images/06846-0005_05-Corner_Dark.jpeg'),
#  Path('data/training_images/06875-0004_04-Corner_Grey.jpeg'),
#  Path('data/training_images/06846-0005_02-Angle.jpeg'),
#  Path('data/training_images/06872-0048_04-Corner_Grey.jpeg'),
#  Path('data/training_images/06846-0005_08-Lifestyle.jpeg'),
#  Path('data/training_images/06846-0005_03-Corner_Light.jpeg'),
#  Path('data/training_images/06778-0001_02-Angle.jpeg'),
#  Path('data/training_images/06778-0001_04-Corner_Grey.jpeg'),
#  Path('data/training_images/06846-0007_08-Lifestyle.jpeg'),
#  Path('data/training_images/06872-0048_07-Detail.jpeg'),
#  Path('data/training_images/06869-0007_01-Over.jpeg'),
#  Path('data/training_images/06869-0007_06-Back.jpeg'),
#  Path('data/training_images/06846-0007_04-Corner_Grey.jpeg'),
#  Path('data/training_images/06846-0005_07-Detail.jpeg'),
#  Path('data/training_images/06869-0007_08-Lifestyle.jpeg'),
#  Path('data/training_images/06834-0007_02-Angle.jpeg'),
#  Path('data/training_images/06865-0016_01-Over.jpeg'),
#  Path('data/training_images/06872-0048_06-Back.jpeg'),
#  Path('data/training_images/06778-0001_06-Back.jpeg'),
#  Path('data/training_images/06869-0007_04-Corner_Grey.jpeg'),
#  Path('data/training_images/06778-0001_07-Detail.jpeg'),
#  Path('data/training_images/06869-0007_03-Corner_Light.jpeg'),
#  Path('data/training_images/06778-0001_01-Over.jpeg'),
#  Path('data/training_images/06875-0004_02-Angle.jpeg'),
#  Path('data/training_images/06846-0007_06-Back.jpeg'),
#  Path('data/training_images/06875-0004_06-Back.jpeg'),
#  Path('data/training_images/06834-0007_05-Corner_Dark.jpeg'),
#  Path('data/training_images/06869-0007_05-Corner_Dark.jpeg'),
#  Path('data/training_images/06846-0005_04-Corner_Grey.jpeg'),
#  Path('data/training_images/06865-0016_08-Lifestyle.jpeg'),
#  Path('data/training_images/06834-0007_03-Corner_Light.jpeg'),
#  Path('data/training_images/06872-0048_01-Over.jpeg'),
#  Path('data/training_images/06846-0005_01-Over.jpeg'),
#  Path('data/training_images/06834-0007_06-Back.jpeg'),
#  Path('data/training_images/06872-0048_08-Lifestyle.jpeg'),
#  Path('data/training_images/06834-0007_01-Over.jpeg'),
#  Path('data/training_images/06872-0048_03-Corner_Light.jpeg'),
#  Path('data/training_images/06865-0016_07-Detail.jpeg'),
#  Path('data/training_images/06875-0004_08-Lifestyle.jpeg'),
#  Path('data/training_images/06846-0007_02-Angle.jpeg'),
#  Path('data/training_images/06846-0007_07-Detail.jpeg'),
#  Path('data/training_images/06834-0007_07-Detail.jpeg'),
#  Path('data/training_images/06865-0016_06-Back.jpeg'),
#  Path('data/training_images/06865-0016_02-Angle.jpeg'),
#  Path('data/training_images/06875-0004_07-Detail.jpeg'),
#  Path('data/training_images/06846-0005_06-Back.jpg'),
#  Path('data/training_images/06865-0016_05-Corner_Dark.jpeg'),
#  Path('data/training_images/06872-0048_02-Angle.jpeg'),
#  Path('data/training_images/06869-0007_02-Angle.jpeg'),
#  Path('data/training_images/.ipynb_checkpoints'),
#  Path('data/training_images/06865-0016_03-Corner_Light.jpeg'),
#  Path('data/training_images/06778-0001_05-Corner_Dark.jpeg'),
#  Path('data/training_images/06875-0004_03-Corner_Light.jpeg'),
#  Path('data/training_images/06875-0004_05-Corner_Dark.jpeg'),
#  Path('data/training_images/06834-0007_08-Lifestyle.jpeg'),
#  Path('data/training_images/06846-0007_01-Over.jpeg'),
#  Path('data/training_images/06872-0048_05-Corner_Dark.jpeg'),
#  Path('data/training_images/06865-0016_04-Corner_Grey.jpeg'),
#  Path('data/training_images/06875-0004_01-Over.jpeg'),
#  Path('data/training_images/06778-0001_03-Corner_Light.jpeg'),
#  Path('data/training_images/06846-0007_03-Corner_Light.jpeg'),
#  Path('data/training_images/06846-0007_05-Corner_Dark.jpeg'),
#  Path('data/training_images/06778-0001_08-Lifestyle.jpeg')]

# %%
rugs = DataBlock(blocks=(ImageBlock, CategoryBlock), 
                 get_items=get_image_files, 
                 splitter=RandomSplitter(),
                 get_y=using_attr(RegexLabeller(r'\d{5}-\d{4}_\d\d-(.+).jpe?g$'), 'name'),
                 item_tfms=Resize(460),
                 batch_tfms=aug_transforms(size=336))
rugs

# %%
dls = rugs.dataloaders(path,bs=8)
dls

# %%
dls.show_batch(max_n=8)

# %%
learn = cnn_learner(dls, resnet34, metrics=error_rate)
learn.fine_tune(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.015705</td>
#       <td>1.861225</td>
#       <td>0.666667</td>
#       <td>00:28</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.245681</td>
#       <td>1.266178</td>
#       <td>0.416667</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.722623</td>
#       <td>0.671547</td>
#       <td>0.250000</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.468519</td>
#       <td>0.508488</td>
#       <td>0.250000</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.206182</td>
#       <td>0.498878</td>
#       <td>0.250000</td>
#       <td>00:37</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn = cnn_learner(dls, resnet34, metrics=error_rate)
lr_min,lr_steep = learn.lr_find()

# %%
print(f"Minimum/10: {lr_min:.2e}, steepest point: {lr_steep:.2e}")
# Out:
# Minimum/10: 1.20e-02, steepest point: 1.10e-06

# %%
learn = cnn_learner(dls, resnet34, metrics=error_rate)
learn.fine_tune(4, base_lr=3e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.810391</td>
#       <td>2.890933</td>
#       <td>0.916667</td>
#       <td>00:28</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.581576</td>
#       <td>1.754922</td>
#       <td>0.666667</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.093338</td>
#       <td>0.729379</td>
#       <td>0.166667</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.569023</td>
#       <td>0.721659</td>
#       <td>0.333333</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.225669</td>
#       <td>0.548191</td>
#       <td>0.333333</td>
#       <td>00:37</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn = cnn_learner(dls, resnet34, metrics=error_rate)
learn.fit_one_cycle(3, 3e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.232725</td>
#       <td>1.811971</td>
#       <td>0.833333</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.268107</td>
#       <td>0.501881</td>
#       <td>0.083333</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.731447</td>
#       <td>0.566801</td>
#       <td>0.250000</td>
#       <td>00:28</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=0.0002511886414140463, lr_steep=2.2908675418875646e-06)

# %%
# update learning rate based on what it found above
learn.fit_one_cycle(6, lr_max=7.5e-4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.751501</td>
#       <td>0.849967</td>
#       <td>0.250000</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.060921</td>
#       <td>7.517735</td>
#       <td>0.500000</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.049885</td>
#       <td>5.940554</td>
#       <td>0.916667</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.957501</td>
#       <td>4.026423</td>
#       <td>0.500000</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.834468</td>
#       <td>1.922609</td>
#       <td>0.166667</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.787959</td>
#       <td>0.994046</td>
#       <td>0.166667</td>
#       <td>00:37</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(5, nrows=5)

# %%
learn.export('model-name.pkl') # can you customize the model name that you export here?
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-63db0fb8c837> in <module>
#       1 # TO DO: see chapter 2 to export the model for production and set up a a script that can make a prediction and rename a file
#       2 # learn.export()
# ----> 3 learn.save()
#
# NameError: name 'learn' is not defined

# %%
root_path = Path()
models_path = Path('models/')
root_path.ls(file_exts='.pkl')

# %%
learn_inf = load_learner(root_path/'models/rug-classifier-aug-NEW-MODEL.pkl')
learn_inf

# %%
print(learn_inf.dls.vocab)
learn_inf.predict('data/test_images/06882-0001_03.tif') # insert test image here from unclassified group
# Out:
# (#8) ['Angle','Back','Corner_Dark','Corner_Grey','Corner_Light','Detail','Lifestyle','Over']
# ('Angle',
#  tensor(0),
#  tensor([9.6491e-01, 2.2278e-07, 2.1416e-02, 1.8529e-04, 3.8291e-03, 6.0185e-06,
#          9.6283e-03, 2.4641e-05]))

# %% [markdown]
# ## Everything in one block

# %%
test_images_path = Path('data/test_images/')
renamed_images_path = Path('data/renamed_images')

files = [file for file in os.listdir(test_images_path)]

for file in files:
    if 'tif' in file:
        path_plus_file = str(test_images_path) + '/' + file
        
        # predict the label using the deep learning model (takes an image as an arg and returns a prediction)
        predicted_label = learn_inf.predict(path_plus_file)[0]
    
        # confirm there was only 1 period in the filename, otherwise things will get messy
        filename_array = file.split('.')
        
        if len(filename_array) > 2:
            raise TooManyPeriodsInFileName(file)
        else:
            file_new_name = filename_array[0] + '_' + predicted_label + '.' + filename_array[1]

        # copy the original to the new folder
        copyfile(path_plus_file, str(renamed_images_path) + '/' + file_new_name)
        print(file_new_name + ' has been created and copied to /' + str(renamed_images_path) + '/')
# Out:
# 06882-0001_03_Angle.tif has been created and copied to /data/renamed_images/
